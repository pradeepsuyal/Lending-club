# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### loading the data

# %%
loans = pd.read_csv('loan_data.csv')

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
loans.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
loans.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#checking for null values

# %%
msno.bar(loans, figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***comparing all feature with credit policy***

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='int.rate',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='int.rate'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='installment',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='installment'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='log.annual.inc',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='log.annual.inc'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='dti',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='dti'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='days.with.cr.line',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='days.with.cr.line'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='inq.last.6mths',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='inq.last.6mths'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='delinq.2yrs',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='delinq.2yrs'>

# %%
plt.figure(figsize=(6,8))
sns.boxenplot(x='credit.policy',y='pub.rec',data=loans,palette="Dark2")
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='pub.rec'>

# %%
loans['credit.policy'].value_counts()
# Out:
# 1    7710
# 0    1868
# Name: credit.policy, dtype: int64

# %%
sns.countplot(data=loans,x='credit.policy')
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
loans[loans['credit.policy']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='Credit.Policy=1')
loans[loans['credit.policy']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='Credit.Policy=0')
plt.legend()
plt.xlabel('FICO')
# Out:
# Text(0.5, 0, 'FICO')

# %% [markdown]
# **similarly figure, except this time select by the not.fully.paid column.**

# %%
plt.figure(figsize=(10,6))
loans[loans['not.fully.paid']==1]['fico'].hist(alpha=0.5,color='blue',
                                              bins=30,label='not.fully.paid=1')
loans[loans['not.fully.paid']==0]['fico'].hist(alpha=0.5,color='red',
                                              bins=30,label='not.fully.paid=0')
plt.legend()
plt.xlabel('FICO')
# Out:
# Text(0.5, 0, 'FICO')

# %%
plt.figure(figsize=(11,7))
sns.countplot(x='purpose',hue='not.fully.paid',data=loans,palette='Set1')
# Out:
# <AxesSubplot:xlabel='purpose', ylabel='count'>

# %% [markdown]
# **Let's see the trend between FICO score and interest rate**

# %%
sns.jointplot(x='fico',y='int.rate',data=loans,color='purple')

# %% [markdown]
# **Creating the  lmplots to see if the trend differed between not.fully.paid and credit.policy**

# %%
plt.figure(figsize=(11,7))
sns.lmplot(y='int.rate',x='fico',data=loans,hue='credit.policy',
           col='not.fully.paid',palette='Set1')

# %%
#correlation
plt.figure(figsize=(15,15))

matrix = np.triu(loans.corr())  
sns.heatmap(loans.corr(),cmap='rainbow',square=True,linecolor='black',linewidths=1, annot = True, mask=matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Setting up the Data

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ### encoding Categorical Features

# %%
cat_feats = ['purpose']

# %%
final_data = pd.get_dummies(loans,columns=cat_feats,drop_first=True)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   credit.policy               9578 non-null   int64
#  1   int.rate                    9578 non-null   float64
#  2   installment                 9578 non-null   float64
#  3   log.annual.inc              9578 non-null   float64
#  4   dti                         9578 non-null   float64
#  5   fico                        9578 non-null   int64
#  6   days.with.cr.line           9578 non-null   float64
#  7   revol.bal                   9578 non-null   int64
#  8   revol.util                  9578 non-null   float64
#  9   inq.last.6mths              9578 non-null   int64
#  10  delinq.2yrs                 9578 non-null   int64
#  11  pub.rec                     9578 non-null   int64
#  12  not.fully.paid              9578 non-null   int64
# ...

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = final_data.drop('not.fully.paid',axis=1)
y = final_data['not.fully.paid']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ### Training a Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Predictions and Evaluation**

# %%
predictions = dtree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('Accuracy of decision tree model is : ',accuracy_score(y_test,predictions))
# Out:
# Accuracy of decision tree model is :  0.8462073764787752

# %% [markdown]
# ### Training the Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=600)

# %% [markdown]
# **predictions and Evaluation**

# %%
predictions = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('Accuracy of Random forest model is : ',accuracy_score(y_test,predictions))
# Out:
# Accuracy of Random forest model is :  0.8462073764787752

# %% [markdown]
# ### Training a KNN Model

# %%
#scaling the data

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(scaled_X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_model.predict(scaled_X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8298538622129437

# %% [markdown]
# we got much better accuracy than DecissionTree
